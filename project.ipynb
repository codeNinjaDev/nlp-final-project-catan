# %% [markdown]
# ## Catan Trade analysis

# %%
import pandas as pd
import numpy as np
import re

# %%
file_df = pd.read_csv("incoming_base_situ.csv")
file_df.head()
# Out:
#    Unnamed: 0 addressee dialogue_act  dialogue_num      doc emitter  \
# 0           0       All        Other           1.0  pilot01      UI
# 1           1       All        Other           1.0  pilot01      UI
# 2           2       All        Other           1.0  pilot01      UI
# 3           3       All        Other           1.0  pilot01      UI
# 4           4       All        Other           1.0  pilot01    Tomm
#
#                     global_id original_turn_number  span_end  subdoc  \
# 0  pilot01_01_stac_1464335345                0.0.1      37.0       1
# 1  pilot01_01_stac_1464335348                0.0.2      72.0       1
# 2  pilot01_01_stac_1464335351                0.0.3     110.0       1
# 3  pilot01_01_stac_1464335354                0.0.4     137.0       1
# 4  pilot01_01_stac_1340734901                    1     153.0       1
#
#    superdoc_num surface_act                      text  turn_id  \
# 0           1.0   Assertion   Markus joined the game.      1.0
# 1           1.0   Assertion     Tomm joined the game.      2.0
# 2           1.0   Assertion  Tomm sat down at seat 3.      3.0
# 3           1.0   Assertion             Game state 0.      4.0
# 4           1.0   Assertion                      ello      5.0
#
#                type parent_schema_id schema_composition  \
# 0  NonplayerSegment                0                  0
# 1  NonplayerSegment                0                  0
# 2  NonplayerSegment                0                  0
# 3  NonplayerSegment                0                  0
# 4           Segment                0                  0
#
#                incoming_relation_id relation_type
# 0                                 0             0
# 1  pilot01_01_jhunter_1464942529752      Sequence
# 2        pilot01_01_stac_1464348718      Sequence
# 3  pilot01_01_jhunter_1464942659602        Result
# 4  pilot01_01_jhunter_1464942702086      Sequence

# %% [markdown]
# ### Separate file into distinct games

# %%
# Remove consecutive duplicate rows based on both 'text' and 'emitter'
df_no_dup = file_df.loc[~((file_df['text'] == file_df['text'].shift()) & (file_df['emitter'] == file_df['emitter'].shift()))]

# Filter the rows where the game started (emitter is 'UI' and text is 'Game started.')
game_started_rows = df_no_dup[(df_no_dup["emitter"] == "UI") & (df_no_dup["text"] == "Game started.")]

# Display the resulting rows
print(game_started_rows.shape)
game_started_rows.index
# Out:
# (45, 19)
# Index([   61,  1480,  2266,  3660,  4855,  6218,  7788,  9138, 10110, 11105,
#        13007, 13972, 14902, 16171, 16944, 17832, 18601, 19475, 20582, 21806,
#        22595, 23358, 24388, 25456, 26796, 27641, 28278, 29059, 30095, 31393,
#        32394, 32746, 33548, 34776, 36000, 37352, 38407, 38941, 39426, 40569,
#        41812, 42367, 43101, 43781, 44659],
#       dtype='int64')

# %%
game_ended_rows  = df_no_dup[(df_no_dup["emitter"] == "Server") & (df_no_dup["text"].str.contains(r"won the game|has expired"))]
print(game_ended_rows.shape)
game_ended_rows.index
# Out:
# (48, 19)
# Index([ 1367,  2211,  3637,  4797,  6120,  6138,  7707,  9075, 10023, 11015,
#        12768, 12823, 13883, 14817, 16090, 16892, 16940, 17740, 18551, 19447,
#        20503, 21771, 22528, 23238, 24351, 25398, 26737, 27608, 28220, 29000,
#        30045, 31331, 32368, 32722, 33517, 34732, 35959, 37322, 38361, 38917,
#        39384, 40461, 41756, 42267, 43007, 43752, 44633, 45451],
#       dtype='int64')

# %%
# Identify start row index
start_index = file_df[(file_df["emitter"] == "UI") & (file_df["text"] == "Game started.")].index

# Identify end row index
end_index = file_df[(file_df["emitter"] == "Server") & (file_df["text"].str.contains("won the game", na=False))].index

# Slice DataFrame for rows between each start and end pair
games = []
for start, end in zip(start_index, end_index):
    if start < end:  # Ensure start comes before end
        games.append(file_df.loc[start:end])  # Include start and end rows

games
# Out:
# [      Unnamed: 0            addressee dialogue_act  dialogue_num      doc  \
#  61            61                  All        Other           1.0  pilot01
#  62            62                  All        Other           1.0  pilot01
#  63            63                  All        Other           1.0  pilot01
#  64            64                  All        Other           1.0  pilot01
#  65            65  Dave, Tomm, rennoc1        Other           1.0  pilot01
#  ...          ...                  ...          ...           ...      ...
#  1363        1363                  All        Other          53.0  pilot01
#  1364        1364                    ?        Offer          53.0  pilot01
#  1365        1365               a port       Accept          53.0  pilot01
#  1366        1366                  All        Other          53.0  pilot01
#  1367        1367                  All        Other          53.0  pilot01
#
#       emitter                   global_id original_turn_number  span_end  \
#  61        UI  pilot01_01_stac_1464335481               14.2.1    2050.0
#  62        UI  pilot01_01_stac_1464335484               14.2.2    2082.0
#  63    Server  pilot01_01_stac_1464335487               14.2.3    2138.0
#  64    Server  pilot01_01_stac_1464335490               14.2.4    2199.0
#  65    Markus  pilot01_01_stac_1454681478                 14.3    2235.0
#  ...      ...                         ...                  ...       ...
#  1363      UI  pilot01_12_stac_1490617939            677.0.0.1     689.0
#  1364      UI  pilot01_12_stac_1464335376              677.0.1     777.0
#  1365  Server  pilot01_12_stac_1464335379                  678     837.0
#  1366  Server  pilot01_12_stac_1464335382                  679     877.0
#  1367  Server  pilot01_12_stac_1464335385              679.0.1     938.0
#
#        subdoc  superdoc_num surface_act  \
#  61         1           1.0   Assertion
#  62         1           1.0   Assertion
#  63         1           1.0   Assertion
#  64         1           1.0   Assertion
#  65         1           1.0   Assertion
#  ...      ...           ...         ...
#  1363      12          39.0   Assertion
#  1364      12          39.0   Assertion
#  1365      12          39.0   Assertion
#  1366      12          39.0   Assertion
#  1367      12          39.0   Assertion
#
#                                                     text  turn_id  \
#  61                                        Game started.     40.0
#  62                                    Board layout set.     41.0
#  63                Randomly picking a starting player...     42.0
#  64           It's rennoc1's turn to build a settlement.     43.0
#  65                                  Amd and off you go!     44.0
#  ...                                                 ...      ...
#  1363                              Tomm has 9 resources.   1035.0
#  1364  Tomm made an offer to trade 2 sheep for 1 whea...   1036.0
#  1365       Tomm traded 2 sheep for 1 wheat from a port.   1037.0
#  1366                           Tomm built a settlement.   1038.0
#  1367          >>> Tomm has won the game with 10 points.   1039.0
#
#                    type                 parent_schema_id schema_composition  \
#  61    NonplayerSegment                                0                  0
#  62    NonplayerSegment                                0                  0
#  63    NonplayerSegment                                0                  0
#  64    NonplayerSegment                                0                  0
#  65             Segment                                0                  0
#  ...                ...                              ...                ...
#  1363  NonplayerSegment     pilot01_12_stacnl_1490779966                EEU
#  1364  NonplayerSegment                                0                  0
#  1365  NonplayerSegment                                0                  0
#  1366  NonplayerSegment                                0                  0
#  1367  NonplayerSegment  pilot01_12_nasher_1516251339991                EEU
#
#                    incoming_relation_id         relation_type
#  61    pilot01_01_jhunter_1464944110475              Sequence
#  62          pilot01_01_stac_1464348722                Result
#  63    pilot01_01_jhunter_1464944575967                Result
#  64    pilot01_01_jhunter_1464944341986                Result
#  65     pilot01_01_nasher_1454937759097               Comment
#  ...                                ...                   ...
#  1363      pilot01_12_stacnl_1490779968          Continuation
#  1364  pilot01_12_jhunter_1465059036447              Sequence
#  1365        pilot01_12_stac_1464349262  Question_answer_pair
#  1366  pilot01_12_jhunter_1465059051251                Result
#  1367                                 0                     0
#
#  [1307 rows x 19 columns],
#        Unnamed: 0 addressee dialogue_act  dialogue_num      doc  emitter  \
#  1480        1480       All        Other          54.0  pilot02       UI
#  1481        1481       All        Other          54.0  pilot02       UI
#  1482        1482       All        Other          54.0  pilot02   Server
#  1483        1483       All        Other          54.0  pilot02   Server
#  1484        1484    Thomas        Other          54.0  pilot02  william
#  ...          ...       ...          ...           ...      ...      ...
#  2207        2207       All        Other          91.0  pilot02   Server
#  2208        2208       All        Other          91.0  pilot02   Server
#  2209        2209       All        Other          91.0  pilot02   Server
#  2210        2210       All        Other          91.0  pilot02   Server
#  2211        2211       All        Other          91.0  pilot02   Server
#
#                         global_id original_turn_number  span_end  subdoc  \
#  1480  pilot02_01_stac_1464256105                6.3.1     771.0       1
#  1481  pilot02_01_stac_1464256108                6.3.2     802.0       1
#  1482  pilot02_01_stac_1464256111                6.3.3     857.0       1
#  1483  pilot02_01_stac_1464256114                6.3.4     917.0       1
#  1484  pilot02_01_stac_1338447672                    7     960.0       1
#  ...                          ...                  ...       ...     ...
#  2207  pilot02_12_stac_1464256105              384.0.6    1018.0      12
#  2208  pilot02_12_stac_1464256108              384.0.7    1067.0      12
#  2209  pilot02_12_stac_1464256111              384.0.8    1134.0      12
#  2210  pilot02_12_stac_1464256114              384.0.9    1190.0      12
#  2211  pilot02_12_stac_1464256117             384.0.10    1255.0      12
#
#        superdoc_num surface_act  \
#  1480          40.0   Assertion
#  1481          40.0   Assertion
#  1482          40.0   Assertion
#  1483          40.0   Assertion
#  1484          40.0   Assertion
#  ...            ...         ...
#  2207          62.0   Assertion
#  2208          62.0   Assertion
#  2209          62.0   Assertion
#  2210          62.0   Assertion
#  2211          62.0   Assertion
#
#                                                   text  turn_id  \
#  1480                                    Game started.   1117.0
#  1481                                Board layout set.   1118.0
#  1482            Randomly picking a starting player...   1119.0
#  1483       It's william's turn to build a settlement.   1120.0
#  1484                     the arrow is pointing at me    1121.0
#  ...                                               ...      ...
#  2207                   william played a Soldier card.   1688.0
#  2208                    william will move the robber.   1689.0
#  2209  william moved the robber, must choose a victim.   1690.0
#  2210             william stole a resource from Thomas   1691.0
#  2211     >>> william has won the game with 11 points.   1692.0
#
#                    type                   parent_schema_id schema_composition  \
#  1480  NonplayerSegment                                  0                  0
#  1481  NonplayerSegment                                  0                  0
#  1482  NonplayerSegment                                  0                  0
#  1483  NonplayerSegment                                  0                  0
#  1484           Segment  pilot02_01_mabrusan_1382432046578                EDU
#  ...                ...                                ...                ...
#  2207  NonplayerSegment                                  0                  0
#  2208  NonplayerSegment         pilot02_12_stac_1464270955                EEU
#  2209  NonplayerSegment         pilot02_12_stac_1464270955                EEU
#  2210  NonplayerSegment         pilot02_12_stac_1464270955                EEU
#  2211  NonplayerSegment                                  0                  0
#
#                   incoming_relation_id relation_type
#  1480    pilot02_01_skar_1464269055705        Result
#  1481       pilot02_01_stac_1464270592        Result
#  1482    pilot02_01_skar_1464269067601        Result
#  1483    pilot02_01_skar_1464269074489        Result
#  1484                                0             0
#  ...                               ...           ...
#  2207  pilot02_12_nasher_1464698705817      Sequence
#  2208                                0             0
#  2209       pilot02_12_stac_1464270957        Result
#  2210       pilot02_12_stac_1464270958        Result
#  2211  pilot02_12_nasher_1464698738942        Result
#
#  [732 rows x 19 columns],
#        Unnamed: 0 addressee dialogue_act  dialogue_num      doc emitter  \
#  2266        2266       All        Other          92.0  pilot03      UI
#  2267        2267       All        Other          92.0  pilot03      UI
#  2268        2268       All        Other          92.0  pilot03      UI
#  2269        2269       All        Other          92.0  pilot03  Server
#  2270        2270       All        Other          92.0  pilot03  Server
#  ...          ...       ...          ...           ...      ...     ...
#  4793        4793       All        Other         189.0  pilot04  Server
#  4794        4794       All        Other         189.0  pilot04  Server
#  4795        4795       All        Other         189.0  pilot04  Server
#  4796        4796       All        Other         189.0  pilot04  Server
#  4797        4797       All        Other         189.0  pilot04  Server
#
#                         global_id original_turn_number  span_end  subdoc  \
#  2266  pilot03_01_stac_1464335502                6.0.1     594.0       1
#  2267  pilot03_01_stac_1464335502                6.0.1     594.0       1
#  2268  pilot03_01_stac_1464335505                6.0.2     625.0       1
#  2269  pilot03_01_stac_1464335508                6.0.3     680.0       1
#  2270  pilot03_01_stac_1464335511                6.0.4     737.0       1
#  ...                          ...                  ...       ...     ...
#  4793  pilot04_13_stac_1464335840              481.0.4    4677.0      13
#  4794  pilot04_13_stac_1464335843              481.0.5    4748.0      13
#  4795  pilot04_13_stac_1464335846              481.0.6    4811.0      13
#  4796  pilot04_13_stac_1464335849                  482    4852.0      13
#  4797  pilot04_13_stac_1464335852              482.0.1    4920.0      13
#
#        superdoc_num surface_act  \
#  2266          63.0   Assertion
#  2267          63.0   Assertion
#  2268          63.0   Assertion
#  2269          63.0   Assertion
#  2270          63.0   Assertion
#  ...            ...         ...
#  4793         109.0   Assertion
#  4794         109.0   Assertion
#  4795         109.0   Assertion
#  4796         109.0   Assertion
#  4797         109.0   Assertion
#
#                                                     text  turn_id  \
#  2266                                      Game started.   1736.0
#  2267                                      Game started.   1736.0
#  2268                                  Board layout set.   1737.0
#  2269              Randomly picking a starting player...   1738.0
#  2270            It's Euan's turn to build a settlement.   1739.0
#  ...                                                 ...      ...
#  4793                  skinnylinny will move the robber.   3572.0
#  4794  skinnylinny moved the robber, must choose a vi...   3573.0
#  4795        skinnylinny stole a resource from Chameleon   3574.0
#  4796                          skinnylinny built a city.   3575.0
#  4797   >>> skinnylinny has won the game with 10 points.   3576.0
#
#                    type              parent_schema_id schema_composition  \
#  2266  NonplayerSegment                             0                  0
#  2267  NonplayerSegment                             0                  0
#  2268  NonplayerSegment                             0                  0
#  2269  NonplayerSegment                             0                  0
#  2270  NonplayerSegment                             0                  0
#  ...                ...                           ...                ...
#  4793  NonplayerSegment  pilot04_13_stacnl_1490699137                EEU
#  4794  NonplayerSegment  pilot04_13_stacnl_1490699137                EEU
#  4795  NonplayerSegment  pilot04_13_stacnl_1490699137                EEU
#  4796  NonplayerSegment                             0                  0
#  4797  NonplayerSegment                             0                  0
#
#                    incoming_relation_id relation_type
#  2266  pilot03_01_jhunter_1465808517543        Result
#  2267  pilot03_01_jhunter_1479464850663      Sequence
#  2268        pilot03_01_stac_1464348746        Result
#  2269  pilot03_01_jhunter_1465808429076        Result
#  2270  pilot03_01_jhunter_1465808431351        Result
#  ...                                ...           ...
#  4793      pilot04_13_stacnl_1490699136        Result
#  4794        pilot04_13_stac_1464349448        Result
#  4795        pilot04_13_stac_1464349449        Result
#  4796   pilot04_13_nasher_1490793787965      Sequence
#  4797  pilot04_13_jhunter_1478367057729        Result
#
#  [2532 rows x 19 columns],
#        Unnamed: 0 addressee dialogue_act  dialogue_num      doc     emitter  \
#  2267        2267       All        Other          92.0  pilot03          UI
#  2268        2268       All        Other          92.0  pilot03          UI
#  2269        2269       All        Other          92.0  pilot03      Server
#  2270        2270       All        Other          92.0  pilot03      Server
#  2271        2271       All        Other          92.0  pilot03  Cardlinger
#  ...          ...       ...          ...           ...      ...         ...
#  6116        6116       All        Other         255.0  pilot14      Server
#  6117        6117       All        Other         255.0  pilot14      Server
#  6118        6118       All        Other         255.0  pilot14      Server
#  6119        6119       All        Other         255.0  pilot14      Server
#  6120        6120       All        Other         255.0  pilot14      Server
#
#                         global_id original_turn_number  span_end  subdoc  \
#  2267  pilot03_01_stac_1464335502                6.0.1     594.0       1
#  2268  pilot03_01_stac_1464335505                6.0.2     625.0       1
#  2269  pilot03_01_stac_1464335508                6.0.3     680.0       1
#  2270  pilot03_01_stac_1464335511                6.0.4     737.0       1
#  2271  pilot03_01_stac_1338384295                    7     776.0       1
#  ...                          ...                  ...       ...     ...
#  6116  pilot14_13_stac_1468422687              489.0.2   13068.0      13
#  6117  pilot14_13_stac_1468422690              489.0.3   13122.0      13
#  6118  pilot14_13_stac_1468422693              489.0.4   13175.0      13
#  6119  pilot14_13_stac_1468422696              489.0.5   13230.0      13
#  6120  pilot14_13_stac_1468422699              489.0.6   13298.0      13
#
#        superdoc_num surface_act  \
#  2267          63.0   Assertion
#  2268          63.0   Assertion
#  2269          63.0   Assertion
#  2270          63.0   Assertion
#  2271          63.0   Assertion
#  ...            ...         ...
#  6116         138.0   Assertion
#  6117         138.0   Assertion
#  6118         138.0   Assertion
#  6119         138.0   Assertion
#  6120         138.0   Assertion
#
#                                                    text  turn_id  \
#  2267                                     Game started.   1736.0
#  2268                                 Board layout set.   1737.0
#  2269             Randomly picking a starting player...   1738.0
#  2270           It's Euan's turn to build a settlement.   1739.0
#  2271                             and _fingers crossed_   1740.0
#  ...                                                ...      ...
#  6116         It's mmatrtajova's turn to roll the dice.   4617.0
#  6117                mmatrtajova played a Soldier card.   4618.0
#  6118                 mmatrtajova will move the robber.   4619.0
#  6119               mmatrtajova stole a resource from J   4620.0
#  6120  >>> mmatrtajova has won the game with 10 points.   4621.0
#
#                    type              parent_schema_id schema_composition  \
#  2267  NonplayerSegment                             0                  0
#  2268  NonplayerSegment                             0                  0
#  2269  NonplayerSegment                             0                  0
#  2270  NonplayerSegment                             0                  0
#  2271           Segment                             0                  0
#  ...                ...                           ...                ...
#  6116  NonplayerSegment                             0                  0
#  6117  NonplayerSegment                             0                  0
#  6118  NonplayerSegment  pilot14_13_stacnl_1468422877                EEU
#  6119  NonplayerSegment  pilot14_13_stacnl_1468422877                EEU
#  6120  NonplayerSegment                             0                  0
#
#                    incoming_relation_id relation_type
#  2267  pilot03_01_jhunter_1479464850663      Sequence
#  2268        pilot03_01_stac_1464348746        Result
#  2269  pilot03_01_jhunter_1465808429076        Result
#  2270  pilot03_01_jhunter_1465808431351        Result
#  2271    pilot03_01_sleva_1340650265684       Comment
#  ...                                ...           ...
#  6116                                 0             0
#  6117   pilot14_13_nasher_1478706495352      Sequence
#  6118                                 0             0
#  6119      pilot14_13_stacnl_1468422879        Result
#  6120   pilot14_13_nasher_1478706510446        Result
#
#  [3854 rows x 19 columns],
#        Unnamed: 0    addressee dialogue_act  dialogue_num      doc emitter  \
#  3660        3660          All        Other         130.0  pilot04      UI
#  3661        3661          All        Other         130.0  pilot04      UI
#  3662        3662          All        Other         130.0  pilot04      UI
#  3663        3663          All        Other         130.0  pilot04  Server
#  3664        3664          All        Other         130.0  pilot04  Server
#  ...          ...          ...          ...           ...      ...     ...
#  6134        6134  mmatrtajova        Other         255.0  pilot14  Markus
#  6135        6135       Markus        Other         255.0  pilot14       J
#  6136        6136          All        Other         255.0  pilot14      UI
#  6137        6137          All        Other         255.0  pilot14      UI
#  6138        6138          All        Other         255.0  pilot14  Server
#
#                         global_id original_turn_number  span_end  subdoc  \
#  3660  pilot04_01_stac_1464335573                6.0.1     576.0       1
#  3661  pilot04_01_stac_1464335573                6.0.1     576.0       1
#  3662  pilot04_01_stac_1464335576                6.0.2     607.0       1
#  3663  pilot04_01_stac_1464335579                6.0.3     662.0       1
#  3664  pilot04_01_stac_1464335582                6.0.4     726.0       1
#  ...                          ...                  ...       ...     ...
#  6134  pilot14_13_stac_1459254699                492.2   13783.0      13
#  6135  pilot14_13_stac_1459254702                  493   13799.0      13
#  6136  pilot14_13_stac_1468422732              493.0.1   13835.0      13
#  6137  pilot14_13_stac_1468422735              493.0.2   13874.0      13
#  6138  pilot14_13_stac_1468422738              493.0.3   13942.0      13
#
#        superdoc_num surface_act  \
#  3660          89.0   Assertion
#  3661          89.0   Assertion
#  3662          89.0   Assertion
#  3663          89.0   Assertion
#  3664          89.0   Assertion
#  ...            ...         ...
#  6134         138.0   Assertion
#  6135         138.0    Question
#  6136         138.0   Assertion
#  6137         138.0   Assertion
#  6138         138.0   Assertion
#
#                                                    text  turn_id  \
#  3660                                     Game started.   2722.0
#  3661                                     Game started.   2722.0
#  3662                                 Board layout set.   2723.0
#  3663             Randomly picking a starting player...   2724.0
#  3664    It's skinnylinny's turn to build a settlement.   2725.0
#  ...                                                ...      ...
#  6134                                  Informatics 3.24   4631.0
#  6135                                             when?   4632.0
#  6136                              ash joined the game.   4633.0
#  6137                           ash sat down at seat 1.   4634.0
#  6138  >>> mmatrtajova has won the game with 10 points.   4635.0
#
#                    type parent_schema_id schema_composition  \
#  3660  NonplayerSegment                0                  0
#  3661  NonplayerSegment                0                  0
#  3662  NonplayerSegment                0                  0
#  3663  NonplayerSegment                0                  0
#  3664  NonplayerSegment                0                  0
#  ...                ...              ...                ...
#  6134           Segment                0                  0
#  6135           Segment                0                  0
#  6136  NonplayerSegment                0                  0
#  6137  NonplayerSegment                0                  0
#  6138  NonplayerSegment                0                  0
#
#                    incoming_relation_id           relation_type
#  3660  pilot04_01_jhunter_1466513681572                Sequence
#  3661  pilot04_01_jhunter_1479477887018                  Result
#  3662        pilot04_01_stac_1464348749                  Result
#  3663  pilot04_01_jhunter_1466513690066                  Result
#  3664  pilot04_01_jhunter_1466513691739                  Result
#  ...                                ...                     ...
#  6134   pilot14_13_nasher_1459340781909    Question_answer_pair
#  6135   pilot14_13_nasher_1459340796477  Clarification_question
#  6136   pilot14_13_nasher_1478706622516                Sequence
#  6137      pilot14_13_stacnl_1468422880                Sequence
#  6138   pilot14_13_nasher_1478706643698                Sequence
#
#  [2479 rows x 19 columns],
#        Unnamed: 0 addressee dialogue_act  dialogue_num      doc emitter  \
#  3661        3661       All        Other         130.0  pilot04      UI
#  3662        3662       All        Other         130.0  pilot04      UI
#  3663        3663       All        Other         130.0  pilot04  Server
#  3664        3664       All        Other         130.0  pilot04  Server
#  3665        3665       All        Other         130.0  pilot04  Server
#  ...          ...       ...          ...           ...      ...     ...
#  7703        7703       All        Other         334.0  pilot20  Server
#  7704        7704       All        Other         334.0  pilot20  Server
#  7705        7705       All        Other         334.0  pilot20  Server
#  7706        7706       All        Other         334.0  pilot20  Server
#  7707        7707       All        Other         334.0  pilot20  Server
#
#                         global_id original_turn_number  span_end  subdoc  \
#  3661  pilot04_01_stac_1464335573                6.0.1     576.0       1
#  3662  pilot04_01_stac_1464335576                6.0.2     607.0       1
#  3663  pilot04_01_stac_1464335579                6.0.3     662.0       1
#  3664  pilot04_01_stac_1464335582                6.0.4     726.0       1
#  3665  pilot04_01_stac_1464335585                    7     771.0       1
#  ...                          ...                  ...       ...     ...
#  7703  pilot20_12_stac_1492523034              577.0.2   16575.0      12
#  7704  pilot20_12_stac_1492523037              577.0.3   16622.0      12
#  7705  pilot20_12_stac_1492523040              577.0.4   16668.0      12
#  7706  pilot20_12_stac_1492523043              577.0.5   16724.0      12
#  7707  pilot20_12_stac_1492523046              577.0.6   16785.0      12
#
#        superdoc_num surface_act  \
#  3661          89.0   Assertion
#  3662          89.0   Assertion
#  3663          89.0   Assertion
#  3664          89.0   Assertion
#  3665          89.0   Assertion
#  ...            ...         ...
#  7703         163.0   Assertion
#  7704         163.0   Assertion
#  7705         163.0   Assertion
#  7706         163.0   Assertion
#  7707         163.0   Assertion
#
#                                                  text  turn_id  \
#  3661                                   Game started.   2722.0
#  3662                               Board layout set.   2723.0
#  3663           Randomly picking a starting player...   2724.0
#  3664  It's skinnylinny's turn to build a settlement.   2725.0
#  3665                 skinnylinny built a settlement.   2726.0
#  ...                                              ...      ...
#  7703              It's inca's turn to roll the dice.   5779.0
#  7704                     inca played a Soldier card.   5780.0
#  7705                      inca will move the robber.   5781.0
#  7706            inca stole a resource from ariachiba   5782.0
#  7707       >>> inca has won the game with 10 points.   5783.0
#
#                    type                 parent_schema_id schema_composition  \
#  3661  NonplayerSegment                                0                  0
#  3662  NonplayerSegment                                0                  0
#  3663  NonplayerSegment                                0                  0
#  3664  NonplayerSegment                                0                  0
#  3665  NonplayerSegment                                0                  0
#  ...                ...                              ...                ...
#  7703  NonplayerSegment                                0                  0
#  7704  NonplayerSegment                                0                  0
#  7705  NonplayerSegment     pilot20_12_stacnl_1492593394                EEU
#  7706  NonplayerSegment     pilot20_12_stacnl_1492593394                EEU
#  7707  NonplayerSegment  pilot20_12_nasher_1516252245211                EEU
#
#                    incoming_relation_id relation_type
#  3661  pilot04_01_jhunter_1479477887018        Result
#  3662        pilot04_01_stac_1464348749        Result
#  3663  pilot04_01_jhunter_1466513690066        Result
#  3664  pilot04_01_jhunter_1466513691739        Result
#  3665        pilot04_01_stac_1464348750        Result
#  ...                                ...           ...
#  7703                                 0             0
#  7704      pilot20_12_stacnl_1492593393      Sequence
#  7705                                 0             0
#  7706      pilot20_12_stacnl_1492593396        Result
#  7707                                 0             0
#
#  [4047 rows x 19 columns],
#        Unnamed: 0 addressee dialogue_act  dialogue_num      doc emitter  \
#  4855        4855       All        Other         190.0  pilot14      UI
#  4856        4856       All        Other         190.0  pilot14      UI
#  4857        4857       All        Other         190.0  pilot14      UI
#  4858        4858       All        Other         190.0  pilot14  Server
#  4859        4859       All        Other         190.0  pilot14  Server
#  ...          ...       ...          ...           ...      ...     ...
#  9071        9071       All        Other         399.0  pilot21      UI
#  9072        9072       All        Other         399.0  pilot21  Server
#  9073        9073       All        Other         399.0  pilot21  Server
#  9074        9074       All        Other         399.0  pilot21  Server
#  9075        9075       All        Other         399.0  pilot21  Server
#
#                         global_id original_turn_number  span_end  subdoc  \
#  4855  pilot14_01_stac_1468421886                0.3.1     470.0       1
#  4856  pilot14_01_stac_1468421886                0.3.1     470.0       1
#  4857  pilot14_01_stac_1468421889                0.3.2     501.0       1
#  4858  pilot14_01_stac_1468421892                0.3.3     556.0       1
#  4859  pilot14_01_stac_1468421895                0.3.4     620.0       1
#  ...                          ...                  ...       ...     ...
#  9071  pilot21_12_stac_1490277973            483.0.0.1   10417.0      12
#  9072  pilot21_12_stac_1490277976            483.0.0.2   10475.0      12
#  9073  pilot21_12_stac_1490277979            483.0.0.3   10533.0      12
#  9074  pilot21_12_stac_1490277982                  484   10572.0      12
#  9075  pilot21_12_stac_1490277985              484.0.1   10638.0      12
#
#        superdoc_num surface_act  \
#  4855         110.0   Assertion
#  4856         110.0   Assertion
#  4857         110.0   Assertion
#  4858         110.0   Assertion
#  4859         110.0   Assertion
#  ...            ...         ...
#  9071         183.0   Assertion
#  9072         183.0   Assertion
#  9073         183.0   Assertion
#  9074         183.0   Assertion
#  9075         183.0   Assertion
#
#                                                  text  turn_id  \
#  4855                                   Game started.   3626.0
#  4856                                   Game started.   3626.0
#  4857                               Board layout set.   3627.0
#  4858           Randomly picking a starting player...   3628.0
#  4859  It's mmatrtajova's turn to build a settlement.   3629.0
#  ...                                              ...      ...
#  9071                     Josephine has 16 resources.   6758.0
#  9072            Josephine bought a development card.   6759.0
#  9073            Josephine bought a development card.   6760.0
#  9074                         Josephine built a road.   6761.0
#  9075  >>> Josephine has won the game with 10 points.   6762.0
#
#                    type                 parent_schema_id schema_composition  \
#  4855  NonplayerSegment                                0                  0
#  4856  NonplayerSegment                                0                  0
#  4857  NonplayerSegment                                0                  0
#  4858  NonplayerSegment                                0                  0
#  4859  NonplayerSegment                                0                  0
#  ...                ...                              ...                ...
#  9071  NonplayerSegment     pilot21_12_stacnl_1490285062                EEU
#  9072  NonplayerSegment                                0                  0
#  9073  NonplayerSegment                                0                  0
#  9074  NonplayerSegment                                0                  0
#  9075  NonplayerSegment  pilot21_12_nasher_1516252974616                EEU
#
#                    incoming_relation_id relation_type
#  4855   pilot14_01_nasher_1478267879732        Result
#  4856  pilot14_01_jhunter_1479982928713        Result
#  4857      pilot14_01_stacnl_1468422025        Result
#  4858   pilot14_01_nasher_1478268220989        Result
#  4859   pilot14_01_nasher_1478268226818        Result
#  ...                                ...           ...
#  9071      pilot21_12_stacnl_1490285064  Continuation
#  9072   pilot21_12_nasher_1490361824626      Sequence
#  9073   pilot21_12_nasher_1490361828382      Sequence
#  9074   pilot21_12_nasher_1490361831730      Sequence
#  9075                                 0             0
#
#  [4221 rows x 19 columns],
#         Unnamed: 0                 addressee dialogue_act  dialogue_num  \
#  4856         4856                       All        Other         190.0
#  4857         4857                       All        Other         190.0
#  4858         4858                       All        Other         190.0
#  4859         4859                       All        Other         190.0
#  4860         4860  Ash, J, ash, mmatrtajova        Other         190.0
#  ...           ...                       ...          ...           ...
#  10019       10019              tomas.kostan       Accept         451.0
#  10020       10020                         ?        Offer         451.0
#  10021       10021                    a port       Accept         451.0
#  10022       10022                       All        Other         451.0
#  10023       10023                       All        Other         451.0
#
#                      doc emitter                            global_id  \
#  4856            pilot14      UI           pilot14_01_stac_1468421886
#  4857            pilot14      UI           pilot14_01_stac_1468421889
#  4858            pilot14  Server           pilot14_01_stac_1468421892
#  4859            pilot14  Server           pilot14_01_stac_1468421895
#  4860            pilot14  Markus           pilot14_01_stac_1459254461
#  ...                 ...     ...                                  ...
#  10019  s1_league1_game1  Server  s1_league1_game1_07_stac_1464335298
#  10020  s1_league1_game1      UI  s1_league1_game1_07_stac_1464335301
#  10021  s1_league1_game1  Server  s1_league1_game1_07_stac_1464335304
#  10022  s1_league1_game1  Server  s1_league1_game1_07_stac_1464335307
#  10023  s1_league1_game1  Server  s1_league1_game1_07_stac_1464335310
#
#        original_turn_number  span_end  subdoc  superdoc_num surface_act  \
#  4856                 0.3.1     470.0       1         110.0   Assertion
#  4857                 0.3.2     501.0       1         110.0   Assertion
#  4858                 0.3.3     556.0       1         110.0   Assertion
#  4859                 0.3.4     620.0       1         110.0   Assertion
#  4860                   0.4     660.0       1         110.0   Assertion
#  ...                    ...       ...     ...           ...         ...
#  10019                  433    2005.0       7         207.0   Assertion
#  10020              433.0.1    2102.0       7         207.0   Assertion
#  10021                  434    2171.0       7         207.0   Assertion
#  10022                  435    2220.0       7         207.0   Assertion
#  10023              435.0.1    2290.0       7         207.0   Assertion
#
#                                                      text  turn_id  \
#  4856                                       Game started.   3626.0
#  4857                                   Board layout set.   3627.0
#  4858               Randomly picking a starting player...   3628.0
#  4859      It's mmatrtajova's turn to build a settlement.   3629.0
#  4860                            You'll only be three ...   3630.0
#  ...                                                  ...      ...
#  10019  gotwood4sheep traded 1 wheat for 1 wood from t...   7494.0
#  10020  gotwood4sheep made an offer to trade 2 wheat f...   7495.0
#  10021  gotwood4sheep traded 2 wheat for 1 sheep from ...   7496.0
#  10022                  gotwood4sheep built a settlement.   7497.0
#  10023  >>> gotwood4sheep has won the game with 10 poi...   7498.0
#
#                     type                          parent_schema_id  \
#  4856   NonplayerSegment                                         0
#  4857   NonplayerSegment                                         0
#  4858   NonplayerSegment                                         0
#  4859   NonplayerSegment                                         0
#  4860            Segment                                         0
#  ...                 ...                                       ...
#  10019  NonplayerSegment                                         0
#  10020  NonplayerSegment                                         0
#  10021  NonplayerSegment                                         0
#  10022  NonplayerSegment                                         0
#  10023  NonplayerSegment  s1_league1_game1_07_nasher_1516039416558
#
#        schema_composition                      incoming_relation_id  \
#  4856                   0          pilot14_01_jhunter_1479982928713
#  4857                   0              pilot14_01_stacnl_1468422025
#  4858                   0           pilot14_01_nasher_1478268220989
#  4859                   0           pilot14_01_nasher_1478268226818
#  4860                   0           pilot14_01_nasher_1459330901769
#  ...                  ...                                       ...
#  10019                  0       s1_league1_game1_07_stac_1464349268
#  10020                  0  s1_league1_game1_07_nasher_1486221021168
#  10021                  0       s1_league1_game1_07_stac_1464349269
#  10022                  0  s1_league1_game1_07_nasher_1486221055417
#  10023                EEU                                         0
#
#                relation_type
#  4856                 Result
#  4857                 Result
#  4858                 Result
#  4859                 Result
#  4860            Explanation
#  ...                     ...
#  10019  Question_answer_pair
#  10020              Sequence
#  10021  Question_answer_pair
#  10022                Result
#  10023                     0
#
#  [5168 rows x 19 columns],
#         Unnamed: 0     addressee dialogue_act  dialogue_num               doc  \
#  6218         6218           All        Other         256.0           pilot20
#  6219         6219           All        Other         256.0           pilot20
#  6220         6220           All        Other         256.0           pilot20
#  6221         6221           All        Other         256.0           pilot20
#  6222         6222           All        Other         256.0           pilot20
#  ...           ...           ...          ...           ...               ...
#  11011       11011             ?        Offer         513.0  s1_league1_game2
#  11012       11012           All        Other         513.0  s1_league1_game2
#  11013       11013  tomas.kostan       Accept         513.0  s1_league1_game2
#  11014       11014           All        Other         513.0  s1_league1_game2
#  11015       11015           All        Other         513.0  s1_league1_game2
#
#        emitter                                global_id original_turn_number  \
#  6218       UI               pilot20_01_stac_1492522011                7.1.2
#  6219       UI               pilot20_01_stac_1492522014                7.1.3
#  6220   Server               pilot20_01_stac_1492522017                7.1.4
#  6221   Server               pilot20_01_stac_1492522020                7.1.5
#  6222       UI               pilot20_01_stac_1492522023                7.1.6
#  ...       ...                                      ...                  ...
#  11011  Server      s1_league1_game2_07_stac_1468416429                  427
#  11012      UI  s1_league1_game2_07_stacutil_1492448008              427.0.1
#  11013  Server      s1_league1_game2_07_stac_1468416436                  428
#  11014  Server      s1_league1_game2_07_stac_1468416439                  429
#  11015  Server      s1_league1_game2_07_stac_1468416442              429.0.1
#
#         span_end  subdoc  superdoc_num surface_act  \
#  6218      871.0       1         139.0   Assertion
#  6219      902.0       1         139.0   Assertion
#  6220      957.0       1         139.0   Assertion
#  6221     1019.0       1         139.0   Assertion
#  6222     1057.0       1         139.0   Assertion
#  ...         ...     ...           ...         ...
#  11011    4567.0       7         235.0   Assertion
#  11012    4604.0       7         235.0   Assertion
#  11013    4683.0       7         235.0   Assertion
#  11014    4730.0       7         235.0   Assertion
#  11015    4798.0       7         235.0   Assertion
#
#                                                      text  turn_id  \
#  6218                                       Game started.   4692.0
#  6219                                   Board layout set.   4693.0
#  6220               Randomly picking a starting player...   4694.0
#  6221        It's ariachiba's turn to build a settlement.   4695.0
#  6222                            Kittles joined the game.   4696.0
#  ...                                                  ...      ...
#  11011  ljaybrad123 made an offer to trade 1 ore, 1 sh...   8286.0
#  11012                              ... from tomas.kostan   8287.0
#  11013  ljaybrad123 traded 1 ore, 1 sheep for 1 clay f...   8288.0
#  11014                    ljaybrad123 built a settlement.   8289.0
#  11015   >>> ljaybrad123 has won the game with 10 points.   8290.0
#
#                     type                          parent_schema_id  \
#  6218   NonplayerSegment                                         0
#  6219   NonplayerSegment                                         0
#  6220   NonplayerSegment                                         0
#  6221   NonplayerSegment                                         0
#  6222   NonplayerSegment                                         0
#  ...                 ...                                       ...
#  11011  NonplayerSegment     s1_league1_game2_07_stacnl_1468416866
#  11012  NonplayerSegment     s1_league1_game2_07_stacnl_1468416866
#  11013  NonplayerSegment                                         0
#  11014  NonplayerSegment                                         0
#  11015  NonplayerSegment  s1_league1_game2_07_nasher_1516040317368
#
#        schema_composition                       incoming_relation_id  \
#  6218                   0              pilot20_01_skar_1492593699213
#  6219                   0               pilot20_01_stacnl_1492592175
#  6220                   0               pilot20_01_stacnl_1492592176
#  6221                   0               pilot20_01_stacnl_1492592177
#  6222                   0            pilot20_01_nasher_1500125126791
#  ...                  ...                                        ...
#  11011                EEU                                          0
#  11012                EEU      s1_league1_game2_07_stacnl_1468416864
#  11013                  0      s1_league1_game2_07_stacnl_1468416867
#  11014                  0  s1_league1_game2_07_jhunter_1480514132323
#  11015                EEU                                          0
#
#                relation_type
#  6218               Sequence
#  6219                 Result
#  6220                 Result
#  6221                 Result
#  6222               Sequence
#  ...                     ...
#  11011                     0
#  11012           Elaboration
#  11013  Question_answer_pair
#  11014                Result
#  11015                     0
#
#  [4798 rows x 19 columns],
#         Unnamed: 0                     addressee dialogue_act  dialogue_num  \
#  7788         7788                           All        Other         335.0
#  7789         7789                           All        Other         335.0
#  7790         7790                           All        Other         335.0
#  7791         7791                           All        Other         335.0
#  7792         7792  Amanda, Charlotte, Katherine        Other         335.0
#  ...           ...                           ...          ...           ...
#  12764       12764                 gotwood4sheep        Other         563.0
#  12765       12765                             ?        Offer         563.0
#  12766       12766                           All       Accept         563.0
#  12767       12767                           All        Other         563.0
#  12768       12768                           All        Other         563.0
#
#                      doc      emitter                            global_id  \
#  7788            pilot21           UI           pilot21_01_stac_1490277353
#  7789            pilot21           UI           pilot21_01_stac_1490277356
#  7790            pilot21       Server           pilot21_01_stac_1490277359
#  7791            pilot21       Server           pilot21_01_stac_1490277362
#  7792            pilot21       Markus       pilot21_01_stacutil_1460120124
#  ...                 ...          ...                                  ...
#  12764  s1_league1_game3  ljaybrad123  s1_league1_game3_14_stac_1368640620
#  12765  s1_league1_game3           UI  s1_league1_game3_14_stac_1468417091
#  12766  s1_league1_game3       Server  s1_league1_game3_14_stac_1468417094
#  12767  s1_league1_game3       Server  s1_league1_game3_14_stac_1468417097
#  12768  s1_league1_game3       Server  s1_league1_game3_14_stac_1468417100
#
#        original_turn_number  span_end  subdoc  superdoc_num surface_act  \
#  7788                 6.0.3     790.0       1         164.0   Assertion
#  7789                 6.0.4     821.0       1         164.0   Assertion
#  7790                 6.0.5     876.0       1         164.0   Assertion
#  7791                 6.0.6     938.0       1         164.0   Assertion
#  7792                   6.1     957.0       1         164.0   Assertion
#  ...                    ...       ...     ...           ...         ...
#  12764                  862    2419.0      14         268.0   Assertion
#  12765              862.0.1    2514.0      14         268.0   Assertion
#  12766                  863    2581.0      14         268.0   Assertion
#  12767                  864    2624.0      14         268.0   Assertion
#  12768              864.0.1    2694.0      14         268.0   Assertion
#
#                                                      text  turn_id  \
#  7788                                       Game started.   5844.0
#  7789                                   Board layout set.   5845.0
#  7790               Randomly picking a starting player...   5846.0
#  7791        It's Josephine's turn to build a settlement.   5847.0
#  7792                                                 Hi,   5848.0
#  ...                                                  ...      ...
#  12764                                        im confused   9610.0
#  12765  gotwood4sheep made an offer to trade 2 wheat f...   9611.0
#  12766  gotwood4sheep traded 2 wheat for 1 ore from a ...   9612.0
#  12767                        gotwood4sheep built a city.   9613.0
#  12768  >>> gotwood4sheep has won the game with 10 poi...   9614.0
#
#                     type                          parent_schema_id  \
# ...
#  43748       43748       All        Other        2490.0      s2_practice2
#  43749       43749       All        Other        2490.0      s2_practice2
#  43750       43750       All        Other        2490.0      s2_practice2
#  43751       43751       All        Other        2490.0      s2_practice2
#  43752       43752       All        Other        2490.0      s2_practice2
#
#             emitter                            global_id original_turn_number  \
#  32746           UI  s2_league5_game1_01_stac_1496239975                4.0.1
#  32747           UI  s2_league5_game1_01_stac_1496239978                4.0.2
#  32748       Server  s2_league5_game1_01_stac_1496239981                4.0.3
#  32749       Server  s2_league5_game1_01_stac_1496239984                4.0.4
#  32750  raefbrisbin  s2_league5_game1_01_stac_1413792994                    5
#  ...            ...                                  ...                  ...
#  43748           UI      s2_practice2_01_stac_1498123961            247.0.0.1
#  43749       Server      s2_practice2_01_stac_1498123964              247.0.1
#  43750       Server      s2_practice2_01_stac_1498123967              247.0.2
#  43751       Server      s2_practice2_01_stac_1498123970                  248
#  43752       Server      s2_practice2_01_stac_1498123973              248.0.1
#
#         span_end  subdoc  superdoc_num surface_act  \
#  32746     590.0       1         708.0   Assertion
#  32747     621.0       1         708.0   Assertion
#  32748     676.0       1         708.0   Assertion
#  32749     739.0       1         708.0   Assertion
#  32750     763.0       1         708.0   Assertion
#  ...         ...     ...           ...         ...
#  43748   28652.0       1         941.0   Assertion
#  43749   28710.0       1         941.0   Assertion
#  43750   28762.0       1         941.0   Assertion
#  43751   28812.0       1         941.0   Assertion
#  43752   28883.0       1         941.0   Assertion
#
#                                                      text  turn_id  \
#  32746                                      Game started.  24707.0
#  32747                                  Board layout set.  24708.0
#  32748              Randomly picking a starting player...  24709.0
#  32749      It's Ghettoette's turn to build a settlement.  24710.0
#  32750                                              yikes  24711.0
#  ...                                                  ...      ...
#  43748                    intemporaliter has 6 resources.  32714.0
#  43749             intemporaliter played a Monopoly card.  32715.0
#  43750                   intemporaliter monopolized clay.  32716.0
#  43751                 intemporaliter built a settlement.  32717.0
#  43752  >>> intemporaliter has won the game with 10 po...  32718.0
#
#                     type                      parent_schema_id  \
#  32746  NonplayerSegment                                     0
#  32747  NonplayerSegment                                     0
#  32748  NonplayerSegment                                     0
#  32749  NonplayerSegment                                     0
#  32750           Segment                                     0
#  ...                 ...                                   ...
#  43748  NonplayerSegment     s2_practice2_01_stacnl_1498201172
#  43749  NonplayerSegment                                     0
#  43750  NonplayerSegment                                     0
#  43751  NonplayerSegment                                     0
#  43752  NonplayerSegment  s2_practice2_01_nasher_1516203496838
#
#        schema_composition                          incoming_relation_id  \
#  32746                  0      s2_league5_game1_01_nasher_1496741671239
#  32747                  0         s2_league5_game1_01_stacnl_1496311056
#  32748                  0         s2_league5_game1_01_stacnl_1496311057
#  32749                  0         s2_league5_game1_01_stacnl_1496311058
#  32750                  0  s2_league5_game1_01_asoubeille_1414136538768
#  ...                  ...                                           ...
#  43748                EEU             s2_practice2_01_stacnl_1498201173
#  43749                  0            s2_practice2_01_skar_1498201227677
#  43750                  0             s2_practice2_01_stacnl_1498201163
#  43751                  0            s2_practice2_01_skar_1498201229841
#  43752                EEU                                             0
#
#        relation_type
#  32746        Result
#  32747        Result
#  32748        Result
#  32749        Result
#  32750       Comment
#  ...             ...
#  43748  Continuation
#  43749      Sequence
#  43750        Result
#  43751      Sequence
#  43752             0
#
#  [11007 rows x 19 columns],
#         Unnamed: 0    addressee dialogue_act  dialogue_num               doc  \
#  33548       33548          All        Other        1866.0  s2_league5_game2
#  33549       33549          All        Other        1866.0  s2_league5_game2
#  33550       33550          All        Other        1866.0  s2_league5_game2
#  33551       33551          All        Other        1866.0  s2_league5_game2
#  33552       33552  raefbrisbin        Other        1866.0  s2_league5_game2
#  ...           ...          ...          ...           ...               ...
#  44629       44629          All        Other        2550.0      s2_practice3
#  44630       44630            ?        Offer        2550.0      s2_practice3
#  44631       44631          All       Accept        2550.0      s2_practice3
#  44632       44632          All        Other        2550.0      s2_practice3
#  44633       44633          All        Other        2550.0      s2_practice3
#
#              emitter                            global_id original_turn_number  \
#  33548            UI  s2_league5_game2_01_stac_1495637323                1.0.5
#  33549            UI  s2_league5_game2_01_stac_1495637326                1.0.6
#  33550        Server  s2_league5_game2_01_stac_1495637329                1.0.7
#  33551        Server  s2_league5_game2_01_stac_1495637332                1.0.8
#  33552  catanstrophe  s2_league5_game2_01_stac_1416393896                    2
#  ...             ...                                  ...                  ...
#  44629        Server      s2_practice3_01_stac_1497884688                  290
#  44630            UI      s2_practice3_01_stac_1497884691              290.0.1
#  44631        Server      s2_practice3_01_stac_1497884694                  291
#  44632        Server      s2_practice3_01_stac_1497884697                  292
#  44633        Server      s2_practice3_01_stac_1497884700              292.0.1
#
#         span_end  subdoc  superdoc_num surface_act  \
#  33548     437.0       1         723.0   Assertion
#  33549     468.0       1         723.0   Assertion
#  33550     523.0       1         723.0   Assertion
#  33551     587.0       1         723.0   Assertion
#  33552     612.0       1         723.0   Assertion
#  ...         ...     ...           ...         ...
#  44629   33596.0       1         963.0   Assertion
#  44630   33693.0       1         963.0   Assertion
#  44631   33762.0       1         963.0   Assertion
#  44632   33798.0       1         963.0   Assertion
#  44633   33861.0       1         963.0   Assertion
#
#                                                      text  turn_id  \
#  33548                                      Game started.  25287.0
#  33549                                  Board layout set.  25288.0
#  33550              Randomly picking a starting player...  25289.0
#  33551     It's raefbrisbin's turn to build a settlement.  25290.0
#  33552                                              hahah  25291.0
#  ...                                                  ...      ...
#  44629                         nelsen built a settlement.  33340.0
#  44630  nelsen made an offer to trade 3 clay, 3 wood f...  33341.0
#  44631  nelsen traded 3 clay, 3 wood for 2 wheat from ...  33342.0
#  44632                               nelsen built a city.  33343.0
#  44633        >>> nelsen has won the game with 10 points.  33344.0
#
#                     type                      parent_schema_id  \
#  33548  NonplayerSegment                                     0
#  33549  NonplayerSegment                                     0
#  33550  NonplayerSegment                                     0
#  33551  NonplayerSegment                                     0
#  33552           Segment                                     0
#  ...                 ...                                   ...
#  44629  NonplayerSegment                                     0
#  44630  NonplayerSegment                                     0
#  44631  NonplayerSegment                                     0
#  44632  NonplayerSegment                                     0
#  44633  NonplayerSegment  s2_practice3_01_nasher_1516203791158
#
#        schema_composition                          incoming_relation_id  \
#  33548                  0      s2_league5_game2_01_nasher_1501175036492
#  33549                  0         s2_league5_game2_01_stacnl_1499151171
#  33550                  0         s2_league5_game2_01_stacnl_1499151172
#  33551                  0         s2_league5_game2_01_stacnl_1499151173
#  33552                  0  s2_league5_game2_01_asoubeille_1416990037750
#  ...                  ...                                           ...
#  44629                  0          s2_practice3_01_nasher_1501336926358
#  44630                  0          s2_practice3_01_nasher_1501336931513
#  44631                  0             s2_practice3_01_stacnl_1499148960
#  44632                  0          s2_practice3_01_nasher_1501336948181
#  44633                EEU                                             0
#
#                relation_type
#  33548              Sequence
#  33549                Result
#  33550                Result
#  33551                Result
#  33552               Comment
#  ...                     ...
#  44629              Sequence
#  44630              Sequence
#  44631  Question_answer_pair
#  44632              Sequence
#  44633                     0
#
#  [11086 rows x 19 columns],
#         Unnamed: 0                   addressee dialogue_act  dialogue_num  \
#  34776       34776                         All        Other        1923.0
#  34777       34777                         All        Other        1923.0
#  34778       34778                         All        Other        1923.0
#  34779       34779                         All        Other        1923.0
#  34780       34780                         All        Other        1923.0
#  ...           ...                         ...          ...           ...
#  45447       45447  Agnes, Kersti, Tyrant Lord        Other        2593.0
#  45448       45448                         All        Other        2593.0
#  45449       45449                         All        Other        2593.0
#  45450       45450                         All        Other        2593.0
#  45451       45451                         All        Other        2593.0
#
#                      doc     emitter                            global_id  \
#  34776  s2_league5_game3          UI  s2_league5_game3_01_stac_1498123239
#  34777  s2_league5_game3          UI  s2_league5_game3_01_stac_1498123242
#  34778  s2_league5_game3      Server  s2_league5_game3_01_stac_1498123245
#  34779  s2_league5_game3      Server  s2_league5_game3_01_stac_1498123248
#  34780  s2_league5_game3  Ghettoette  s2_league5_game3_01_stac_1443692191
#  ...                 ...         ...                                  ...
#  45447      s2_practice4    Sparkles      s2_practice4_01_stac_1458311307
#  45448      s2_practice4      Server      s2_practice4_01_stac_1497886330
#  45449      s2_practice4      Server      s2_practice4_01_stac_1497886333
#  45450      s2_practice4      Server      s2_practice4_01_stac_1497886336
#  45451      s2_practice4      Server      s2_practice4_01_stac_1497886339
#
#        original_turn_number  span_end  subdoc  superdoc_num surface_act  \
#  34776                1.0.1     409.0       1         753.0   Assertion
#  34777                1.0.2     440.0       1         753.0   Assertion
#  34778                1.0.3     495.0       1         753.0   Assertion
#  34779                1.0.4     555.0       1         753.0   Assertion
#  34780                    2     585.0       1         753.0   Assertion
#  ...                    ...       ...     ...           ...         ...
#  45447                  312   30375.0       1         983.0   Assertion
#  45448              312.0.1   30426.0       1         983.0   Assertion
#  45449              312.0.2   30476.0       1         983.0   Assertion
#  45450              312.0.3   30533.0       1         983.0   Assertion
#  45451              312.0.4   30598.0       1         983.0   Assertion
#
#                                                  text  turn_id  \
#  34776                                  Game started.  26139.0
#  34777                              Board layout set.  26140.0
#  34778          Randomly picking a starting player...  26141.0
#  34779     It's zorburt's turn to build a settlement.  26142.0
#  34780                                   hey everyone  26143.0
#  ...                                              ...      ...
#  45447                                  good game all  33923.0
#  45448                Sparkles played a Soldier card.  33924.0
#  45449                 Sparkles will move the robber.  33925.0
#  45450          Sparkles stole a resource from Kersti  33926.0
#  45451  >>> Sparkles has won the game with 11 points.  33927.0
#
#                     type                      parent_schema_id  \
#  34776  NonplayerSegment                                     0
#  34777  NonplayerSegment                                     0
#  34778  NonplayerSegment                                     0
#  34779  NonplayerSegment                                     0
#  34780           Segment                                     0
#  ...                 ...                                   ...
#  45447           Segment                                     0
#  45448  NonplayerSegment                                     0
#  45449  NonplayerSegment     s2_practice4_01_stacnl_1499150422
#  45450  NonplayerSegment     s2_practice4_01_stacnl_1499150422
#  45451  NonplayerSegment  s2_practice4_01_nasher_1516204147201
#
#        schema_composition                      incoming_relation_id  \
#  34776                  0  s2_league5_game3_01_nasher_1501167263912
#  34777                  0     s2_league5_game3_01_stacnl_1498198799
#  34778                  0     s2_league5_game3_01_stacnl_1498198800
#  34779                  0     s2_league5_game3_01_stacnl_1498198801
#  34780                  0    s2_league5_game3_01_skar_1444730861169
#  ...                  ...                                       ...
#  45447                  0        s2_practice4_01_skar_1460043427546
#  45448                  0         s2_practice4_01_stacnl_1499150421
#  45449                EEU                                         0
#  45450                EEU         s2_practice4_01_stacnl_1499150424
#  45451                EEU                                         0
#
#           relation_type
#  34776           Result
#  34777           Result
#  34778           Result
#  34779           Result
#  34780  Acknowledgement
#  ...                ...
#  45447          Comment
#  45448         Sequence
#  45449                0
#  45450           Result
#  45451                0
#
#  [10676 rows x 19 columns]]

# %% [markdown]
# ### Look at first_game

# %% [markdown]
# #### Let's look at successful offers

# %%
game_one = games[0]

successful_offers = game_one[(game_one["dialogue_act"] == "Accept") & 
                             (game_one["emitter"] == "Server") & 
                             (game_one["addressee"] != "?") & 
                             (game_one["addressee"] != "the bank")]
successful_offers.head()

# %%
def create_prompt_from_offer(curr_game, offer_row, prefix="", sentiment="", only_use_start_of_turn=False, offer_sentiment=""):
    index = offer_row.name
    trade_accepted_by = offer_row["addressee"]
    trade_offered_by = offer_row["text"].split()[0]

    chat_log = curr_game.loc[:index - 1]
    last_game_event = chat_log[(chat_log["addressee"] == "All") & (chat_log["emitter"] == "UI") & (chat_log["type"] == "NonplayerSegment")].iloc[-1]

    if only_use_start_of_turn:
        chat_log = chat_log.loc[:last_game_event.name]
    persona = (
        f"You are {trade_accepted_by}. The previous messages are chat log of an ongoing Catan game. " + 
        f"Your goal is to win this game of Catan. This trade is offered: {offer_row['text']}. " +
        (trade_accepted_by + ' remarks \"' + offer_sentiment + '\"' if offer_sentiment else '') + 
        f" {sentiment}. " +
        "Now, you must make a decision. Do you accept or reject this trade? Explain and justify your answer in detail. Format your answer in JSON like: " +
        "{'decision': 'yes/no', 'explanation': '...'}" +
        " Do not include any text outside of the JSON structure."
    )
 


    return prefix + chat_log.to_string() + persona

# %%
prompt = create_prompt_from_offer(game_one, successful_offers.iloc[0])

# %%
import os
# Access an environment variable
key = os.getenv('gemini_api_key')

# %%
import google.generativeai as genai

genai.configure(api_key=key)

# %%
data_manual_file = genai.upload_file(path="stac-annotation-manual.pdf", display_name="STAC Manual")
file_uri = data_manual_file.uri

rules_file = genai.upload_file(path="catan_base_rules_2020_200707.pdf", display_name="Catan Rules")
rules_uri = rules_file.uri

# %%
model = genai.GenerativeModel("gemini-1.5-flash")
prompt = create_prompt_from_offer(game_one, successful_offers.iloc[0], prefix="Understand the dataset by using the manual. ", sentiment="Use your knowledge of Catan (from the rules document) and strategy to try to estimate the current state of the game from the log and make a smart and logical choice. First, explain what the trade offers is and clearly state which players are getting which resource. State each assumption you make logically in order and how the next statement flows from the other. Base most of your reasoning based on the events in the log/game history. Explain it from the perspective of your persona", offer_sentiment="Dave, you will be really dumb if you accept this trade!", only_use_start_of_turn=True)
print(prompt)
response = model.generate_content([
    {"file_data": {"mime_type": "application/pdf", "file_uri": file_uri}},
    {"file_data": {"mime_type": "application/pdf", "file_uri": rules_uri}},
    {"text": prompt}
])
print(response.text)
# Out:
# Understand the dataset by using the manual.      Unnamed: 0            addressee dialogue_act  dialogue_num      doc  emitter                   global_id original_turn_number  span_end  subdoc  superdoc_num surface_act                                                                      text  turn_id              type                     parent_schema_id schema_composition                 incoming_relation_id           relation_type
# 61           61                  All        Other           1.0  pilot01       UI  pilot01_01_stac_1464335481               14.2.1    2050.0       1           1.0   Assertion                                                             Game started.     40.0  NonplayerSegment                                    0                  0     pilot01_01_jhunter_1464944110475                Sequence
# 62           62                  All        Other           1.0  pilot01       UI  pilot01_01_stac_1464335484               14.2.2    2082.0       1           1.0   Assertion                                                         Board layout set.     41.0  NonplayerSegment                                    0                  0           pilot01_01_stac_1464348722                  Result
# 63           63                  All        Other           1.0  pilot01   Server  pilot01_01_stac_1464335487               14.2.3    2138.0       1           1.0   Assertion                                     Randomly picking a starting player...     42.0  NonplayerSegment                                    0                  0     pilot01_01_jhunter_1464944575967                  Result
# 64           64                  All        Other           1.0  pilot01   Server  pilot01_01_stac_1464335490               14.2.4    2199.0       1           1.0   Assertion                                It's rennoc1's turn to build a settlement.     43.0  NonplayerSegment                                    0                  0     pilot01_01_jhunter_1464944341986                  Result
# 65           65  Dave, Tomm, rennoc1        Other           1.0  pilot01   Markus  pilot01_01_stac_1454681478                 14.3    2235.0       1           1.0   Assertion                                                       Amd and off you go!     44.0           Segment                                    0                  0      pilot01_01_nasher_1454937759097                 Comment
# 66           66                  All        Other           1.0  pilot01   Server  pilot01_01_stac_1464335496                   15    2277.0       1           1.0   Assertion                                               rennoc1 built a settlement.     45.0  NonplayerSegment                                    0                  0           pilot01_01_stac_1464348723                  Result
# 67           67                  All        Other           1.0  pilot01   Server  pilot01_01_stac_1464335499               15.0.1    2332.0       1           1.0   Assertion                                      It's rennoc1's turn to build a road.     46.0  NonplayerSegment                                    0                  0     pilot01_01_jhunter_1464944184947                  Result
# 68           68                  All        Other           1.0  pilot01   Server  pilot01_01_stac_1464335502                   16    2368.0       1           1.0   Assertion                                                     rennoc1 built a road.     47.0  NonplayerSegment                                    0                  0           pilot01_01_stac_1464348724                  Result
# 69           69                  All        Other           1.0  pilot01   Server  pilot01_01_stac_1464335505               16.0.1    2426.0       1           1.0   Assertion                                   It's Dave's turn to build a settlement.     48.0  NonplayerSegment                                    0                  0     pilot01_01_jhunter_1464944189159                  Result
# 70           70                  All        Other           1.0  pilot01   Server  pilot01_01_stac_1464335508                   17    2465.0       1           1.0   Assertion                                                  Dave built a settlement.     49.0  NonplayerSegment                                    0                  0           pilot01_01_stac_1464348725                  Result
# 71           71                  All        Other           1.0  pilot01   Server  pilot01_01_stac_1464335511               17.0.1    2517.0       1           1.0   Assertion                                         It's Dave's turn to build a road.     50.0  NonplayerSegment                                    0                  0     pilot01_01_jhunter_1464944325081                  Result
# 72           72                  All        Other           1.0  pilot01   Server  pilot01_01_stac_1464335514                   18    2550.0       1           1.0   Assertion                                                        Dave built a road.     51.0  NonplayerSegment                                    0                  0           pilot01_01_stac_1464348726                  Result
# 73           73                  All        Other           1.0  pilot01   Server  pilot01_01_stac_1464335517               18.0.1    2608.0       1           1.0   Assertion                                   It's Tomm's turn to build a settlement.     52.0  NonplayerSegment                                    0                  0     pilot01_01_jhunter_1464944193347                  Result
# 74           74                  All        Other           1.0  pilot01   Server  pilot01_01_stac_1464335520                   19    2647.0       1           1.0   Assertion                                                  Tomm built a settlement.     53.0  NonplayerSegment                                    0                  0           pilot01_01_stac_1464348727                  Result
# 75           75                  All        Other           1.0  pilot01   Server  pilot01_01_stac_1464335523               19.0.1    2699.0       1           1.0   Assertion                                         It's Tomm's turn to build a road.     54.0  NonplayerSegment                                    0                  0     pilot01_01_jhunter_1464944196728                  Result
# 76           76                  All        Other           1.0  pilot01   Server  pilot01_01_stac_1464335526                   20    2732.0       1           1.0   Assertion                                                        Tomm built a road.     55.0  NonplayerSegment                                    0                  0           pilot01_01_stac_1464348728                  Result
# 77           77                  All        Other           1.0  pilot01   Server  pilot01_01_stac_1464335529               20.0.1    2790.0       1           1.0   Assertion                                   It's Tomm's turn to build a settlement.     56.0  NonplayerSegment                                    0                  0     pilot01_01_jhunter_1464944199372                  Result
# 78           78                  All        Other           1.0  pilot01   Server  pilot01_01_stac_1464335532                   21    2829.0       1           1.0   Assertion                                                  Tomm built a settlement.     57.0  NonplayerSegment                                    0                  0           pilot01_01_stac_1464348729                  Result
# 79           79                  All        Other           1.0  pilot01   Server  pilot01_01_stac_1464335535               21.0.1    2881.0       1           1.0   Assertion                                         It's Tomm's turn to build a road.     58.0  NonplayerSegment                                    0                  0     pilot01_01_jhunter_1464944207630                  Result
# 80           80                  All        Other           1.0  pilot01   Server  pilot01_01_stac_1464335538                   22    2914.0       1           1.0   Assertion                                                        Tomm built a road.     59.0  NonplayerSegment                                    0                  0           pilot01_01_stac_1464348730                  Result
# 81           81                  All        Other           1.0  pilot01   Server  pilot01_01_stac_1464335541               22.0.1    2972.0       1           1.0   Assertion                                   It's Dave's turn to build a settlement.     60.0  NonplayerSegment                                    0                  0     pilot01_01_jhunter_1464944212306                  Result
# 82           82                  All        Other           1.0  pilot01   Server  pilot01_01_stac_1464335544                   23    3011.0       1           1.0   Assertion                                                  Dave built a settlement.     61.0  NonplayerSegment                                    0                  0           pilot01_01_stac_1464348731                  Result
# 83           83                  All        Other           1.0  pilot01   Server  pilot01_01_stac_1464335547               23.0.1    3063.0       1           1.0   Assertion                                         It's Dave's turn to build a road.     62.0  NonplayerSegment                                    0                  0     pilot01_01_jhunter_1464944216669                  Result
# 84           84                  All        Other           1.0  pilot01   Server  pilot01_01_stac_1464335550                   24    3096.0       1           1.0   Assertion                                                        Dave built a road.     63.0  NonplayerSegment                                    0                  0           pilot01_01_stac_1464348732                  Result
# 85           85                  All        Other           1.0  pilot01   Server  pilot01_01_stac_1464335553               24.0.1    3157.0       1           1.0   Assertion                                It's rennoc1's turn to build a settlement.     64.0  NonplayerSegment                                    0                  0     pilot01_01_jhunter_1464944234404                  Result
# 86           86                  All        Other           1.0  pilot01   Server  pilot01_01_stac_1464335556                   25    3199.0       1           1.0   Assertion                                               rennoc1 built a settlement.     65.0  NonplayerSegment                                    0                  0           pilot01_01_stac_1464348733                  Result
# 87           87                  All        Other           1.0  pilot01   Server  pilot01_01_stac_1464335559               25.0.1    3254.0       1           1.0   Assertion                                      It's rennoc1's turn to build a road.     66.0  NonplayerSegment                                    0                  0     pilot01_01_jhunter_1464944236100                  Result
# 88           88                  All        Other           1.0  pilot01   Server  pilot01_01_stac_1464335562                   26    3290.0       1           1.0   Assertion                                                     rennoc1 built a road.     67.0  NonplayerSegment                                    0                  0           pilot01_01_stac_1464348734                  Result
# 89           89                  All        Other           2.0  pilot01   Server  pilot01_01_stac_1464335565               26.0.1    3346.0       1           2.0   Assertion                                     It's rennoc1's turn to roll the dice.     68.0  NonplayerSegment                                    0                  0                                    0                       0
# 90           90                  All        Other           2.0  pilot01   Server  pilot01_01_stac_1464335569                   27    3388.0       1           2.0   Assertion                                               rennoc1 rolled a 5 and a 6.     69.0  NonplayerSegment                                    0                  0           pilot01_01_stac_1464348735                  Result
# 91           91                  All        Other           2.0  pilot01   Server  pilot01_01_stac_1464335572                   28    3424.0       1           2.0   Assertion                                                     rennoc1 gets 1 wheat.     70.0  NonplayerSegment           pilot01_01_stac_1464348736                EEU                                    0                       0
# 92           92                  All        Other           2.0  pilot01   Server  pilot01_01_stac_1464335573                   28    3443.0       1           2.0   Assertion                                                        Tomm gets 1 wheat.     70.0  NonplayerSegment           pilot01_01_stac_1464348736                EEU           pilot01_01_stac_1464348738            Continuation
# 93           93                  All        Other           2.0  pilot01       UI  pilot01_01_stac_1490618128             28.0.0.1    3484.0       1           2.0   Assertion                                                  rennoc1 has 4 resources.     71.0  NonplayerSegment         pilot01_01_stacnl_1490777833                EEU                                    0                       0
# 94           94                  All        Other           2.0  pilot01       UI  pilot01_01_stac_1490618129             28.0.0.1    3506.0       1           2.0   Assertion                                                     Dave has 3 resources.     71.0  NonplayerSegment         pilot01_01_stacnl_1490777833                EEU         pilot01_01_stacnl_1490777834            Continuation
# 95           95                  All        Other           2.0  pilot01       UI  pilot01_01_stac_1490618130             28.0.0.1    3528.0       1           2.0   Assertion                                                     Tomm has 4 resources.     71.0  NonplayerSegment         pilot01_01_stacnl_1490777833                EEU         pilot01_01_stacnl_1490777835            Continuation
# 96           96                  All        Other           2.0  pilot01  rennoc1  pilot01_01_stac_1341014901                   29    3578.0       1           2.0    Question                                        so anyone else played this before?     72.0           Segment                                    0                  0     pilot01_01_jhunter_1467014872054                Sequence
# 97           97              rennoc1        Other           2.0  pilot01     Dave  pilot01_01_stac_1341024901                   30    3604.0       1           2.0   Assertion                                                             I haven't, no     73.0           Segment                                    0                  0       pilot01_01_sleva_1340914250405    Question_answer_pair
# 98           98              rennoc1        Other           2.0  pilot01     Tomm  pilot01_01_stac_1341034901                   31    3633.0       1           2.0   Assertion                                                          Yes, a little...     74.0           Segment                                    0                  0       pilot01_01_sleva_1340914456593    Question_answer_pair
# 99           99              rennoc1        Other           2.0  pilot01     Tomm  pilot01_01_stac_1341034902                   31    3661.0       1           2.0   Assertion                                               but I was never good at it.     74.0           Segment                                    0                  0       pilot01_01_sleva_1340914490744                Contrast
# 100         100              rennoc1        Other           2.0  pilot01     Dave  pilot01_01_stac_1341044901                   32    3703.0       1           2.0    Question                                             is it still your turn rennoc?     75.0           Segment                                    0                  0      pilot01_01_nasher_1374068608036  Clarification_question
# 101         101                 Dave        Other           2.0  pilot01  rennoc1  pilot01_01_stac_1341054901                   33    3724.0       1           2.0   Assertion                                                                     yeah,     76.0           Segment                                    0                  0       pilot01_01_sleva_1340914519915    Question_answer_pair
# 102         102                  All        Other           2.0  pilot01       UI  pilot01_01_stac_1464335592               33.0.1    3764.0       1           2.0   Assertion                                                 rennoc1 ended their turn.     77.0  NonplayerSegment                                    0                  0     pilot01_01_jhunter_1464944283349                Sequence
# 103         103                  All        Other           3.0  pilot01   Server  pilot01_02_stac_1464335345               33.0.2      53.0       2           3.0   Assertion                                        It's Dave's turn to roll the dice.     78.0  NonplayerSegment                                    0                  0                                    0                       0
# 104         104                  All        Other           3.0  pilot01   Server  pilot01_02_stac_1464335349                   34      92.0       2           3.0   Assertion                                                  Dave rolled a 2 and a 4.     79.0  NonplayerSegment                                    0                  0           pilot01_02_stac_1464348762                  Result
# 105         105                  All        Other           3.0  pilot01   Server  pilot01_02_stac_1464335352                   35     128.0       2           3.0   Assertion                                                     rennoc1 gets 1 sheep.     80.0  NonplayerSegment           pilot01_02_stac_1464348763                EEU                                    0                       0
# 106         106                  All        Other           3.0  pilot01   Server  pilot01_02_stac_1464335353                   35     147.0       2           3.0   Assertion                                                        Tomm gets 1 sheep.     80.0  NonplayerSegment           pilot01_02_stac_1464348763                EEU           pilot01_02_stac_1464348765            Continuation
# 107         107                  All        Other           3.0  pilot01       UI  pilot01_02_stac_1490617906             35.0.0.1     188.0       2           3.0   Assertion                                                  rennoc1 has 5 resources.     81.0  NonplayerSegment        pilot01_02_skar_1490793666319                EEU                                    0                       0
# 108         108                  All        Other           3.0  pilot01       UI  pilot01_02_stac_1490617907             35.0.0.1     210.0       2           3.0   Assertion                                                     Dave has 3 resources.     81.0  NonplayerSegment        pilot01_02_skar_1490793666319                EEU        pilot01_02_skar_1490793691737            Continuation
# 109         109                  All        Other           3.0  pilot01       UI  pilot01_02_stac_1490617908             35.0.0.1     232.0       2           3.0   Assertion                                                     Tomm has 5 resources.     81.0  NonplayerSegment        pilot01_02_skar_1490793666319                EEU        pilot01_02_skar_1490793693643            Continuation
# 110         110                  All        Other           3.0  pilot01       UI  pilot01_02_stac_1464335356               35.0.1     269.0       2           3.0   Assertion                                                    Dave ended their turn.     82.0  NonplayerSegment                                    0                  0     pilot01_02_jhunter_1464944627184                Sequence
# 111         111                  All        Other           4.0  pilot01   Server  pilot01_02_stac_1464335359               35.0.2     322.0       2           3.0   Assertion                                        It's Tomm's turn to roll the dice.     83.0  NonplayerSegment                                    0                  0                                    0                       0
# 112         112                  All        Other           4.0  pilot01   Server  pilot01_02_stac_1464335363                   36     361.0       2           3.0   Assertion                                                  Tomm rolled a 6 and a 5.     84.0  NonplayerSegment                                    0                  0           pilot01_02_stac_1464348766                  Result
# 113         113                  All        Other           4.0  pilot01   Server  pilot01_02_stac_1464335366                   37     397.0       2           3.0   Assertion                                                     rennoc1 gets 1 wheat.     85.0  NonplayerSegment           pilot01_02_stac_1464348777                EEU                                    0                       0
# 114         114                  All        Other           4.0  pilot01   Server  pilot01_02_stac_1464335367                   37     416.0       2           3.0   Assertion                                                        Tomm gets 1 wheat.     85.0  NonplayerSegment           pilot01_02_stac_1464348777                EEU           pilot01_02_stac_1464348779            Continuation
# 115         115                  All        Other           4.0  pilot01       UI  pilot01_02_stac_1490617925             37.0.0.1     457.0       2           3.0   Assertion                                                  rennoc1 has 6 resources.     86.0  NonplayerSegment        pilot01_02_skar_1490793715919                EEU                                    0                       0
# 116         116                  All        Other           4.0  pilot01       UI  pilot01_02_stac_1490617926             37.0.0.1     479.0       2           3.0   Assertion                                                     Dave has 3 resources.     86.0  NonplayerSegment        pilot01_02_skar_1490793715919                EEU        pilot01_02_skar_1490793739178            Continuation
# 117         117                  All        Other           4.0  pilot01       UI  pilot01_02_stac_1490617927             37.0.0.1     501.0       2           3.0   Assertion                                                     Tomm has 6 resources.     86.0  NonplayerSegment        pilot01_02_skar_1490793715919                EEU        pilot01_02_skar_1490793740972            Continuation
# 118         118                  All        Other           4.0  pilot01       UI  pilot01_02_stac_1464335370               37.0.1     574.0       2           3.0   Assertion                Tomm made an offer to trade  for  from the bank or a port.     87.0  NonplayerSegment     pilot01_02_jhunter_1487683198150                EEU                                    0                       0
# 119         119                 Tomm        Other           4.0  pilot01   Server  pilot01_02_stac_1464335373               37.0.2     619.0       2           3.0   Assertion                                                You can't make that trade.     88.0  NonplayerSegment     pilot01_02_jhunter_1487683198150                EEU           pilot01_02_stac_1464348769              Correction
# 120         120                    ?        Offer           4.0  pilot01       UI  pilot01_02_stac_1464335376               37.0.3     706.0       2           3.0   Assertion  Tomm made an offer to trade 3 wheat for 1 sheep from the bank or a port.     89.0  NonplayerSegment     pilot01_02_jhunter_1487683226849                EEU                                    0                       0
# 121         121                 Tomm        Other           4.0  pilot01   Server  pilot01_02_stac_1464335379               37.0.4     751.0       2           3.0   Assertion                                                You can't make that trade.     90.0  NonplayerSegment     pilot01_02_jhunter_1487683226849                EEU           pilot01_02_stac_1464348770              Correction
# 122         122                  All        Other           4.0  pilot01       UI  pilot01_02_stac_1464335382               37.0.5     824.0       2           3.0   Assertion                Tomm made an offer to trade  for  from the bank or a port.     91.0  NonplayerSegment     pilot01_02_jhunter_1487683235930                EEU                                    0                       0
# 123         123                 Tomm        Other           4.0  pilot01   Server  pilot01_02_stac_1464335385               37.0.6     869.0       2           3.0   Assertion                                                You can't make that trade.     92.0  NonplayerSegment     pilot01_02_jhunter_1487683235930                EEU           pilot01_02_stac_1464348773              Correction
# 124         124                  All        Other           4.0  pilot01       UI  pilot01_02_stac_1464335388               37.0.7     942.0       2           3.0   Assertion                Tomm made an offer to trade  for  from the bank or a port.     93.0  NonplayerSegment     pilot01_02_jhunter_1487683243651                EEU                                    0                       0
# 125         125                 Tomm        Other           4.0  pilot01   Server  pilot01_02_stac_1464335391               37.0.8     987.0       2           3.0   Assertion                                                You can't make that trade.     94.0  NonplayerSegment     pilot01_02_jhunter_1487683243651                EEU     pilot01_02_jhunter_1464944912746              Correction
# 126         126                  All        Other           4.0  pilot01       UI  pilot01_02_stac_1464335394               37.0.9    1024.0       2           3.0   Assertion                                                    Tomm ended their turn.     95.0  NonplayerSegment                                    0                  0     pilot01_02_jhunter_1464944921002                  Result
# 127         127                  All        Other           5.0  pilot01   Server  pilot01_02_stac_1464335397              37.0.10    1081.0       2           3.0   Assertion                                     It's rennoc1's turn to roll the dice.     96.0  NonplayerSegment                                    0                  0                                    0                       0
# 128         128                  All        Other           5.0  pilot01   Server  pilot01_02_stac_1464335401                   38    1123.0       2           3.0   Assertion                                               rennoc1 rolled a 4 and a 1.     97.0  NonplayerSegment                                    0                  0           pilot01_02_stac_1464348780                  Result
# 129         129                  All        Other           5.0  pilot01   Server  pilot01_02_stac_1464335404                   39    1158.0       2           3.0   Assertion                                                      rennoc1 gets 2 clay.     98.0  NonplayerSegment           pilot01_02_stac_1464348781                EEU                                    0                       0
# 130         130                  All        Other           5.0  pilot01   Server  pilot01_02_stac_1464335405                   39    1177.0       2           3.0   Assertion                                                        Dave gets 1 wheat.     98.0  NonplayerSegment           pilot01_02_stac_1464348781                EEU           pilot01_02_stac_1464348783            Continuation
# 131         131                  All        Other           5.0  pilot01       UI  pilot01_02_stac_1490617968             39.0.0.1    1218.0       2           3.0   Assertion                                                  rennoc1 has 8 resources.     99.0  NonplayerSegment        pilot01_02_skar_1490793766849                EEU                                    0                       0
# 132         132                  All        Other           5.0  pilot01       UI  pilot01_02_stac_1490617969             39.0.0.1    1240.0       2           3.0   Assertion                                                     Dave has 4 resources.     99.0  NonplayerSegment        pilot01_02_skar_1490793766849                EEU        pilot01_02_skar_1490793782229            Continuation
# 133         133                  All        Other           5.0  pilot01       UI  pilot01_02_stac_1490617970             39.0.0.1    1262.0       2           3.0   Assertion                                                     Tomm has 6 resources.     99.0  NonplayerSegment        pilot01_02_skar_1490793766849                EEU        pilot01_02_skar_1490793784235            Continuation
# 134         134                  All        Other           5.0  pilot01       UI  pilot01_02_stac_1464335408               39.0.1    1302.0       2           3.0   Assertion                                                 rennoc1 ended their turn.    100.0  NonplayerSegment                                    0                  0     pilot01_02_jhunter_1464944970229                Sequence
# 135         135                  All        Other           6.0  pilot01   Server  pilot01_02_stac_1464335411               39.0.2    1355.0       2           3.0   Assertion                                        It's Dave's turn to roll the dice.    101.0  NonplayerSegment                                    0                  0                                    0                       0
# 136         136                  All        Other           6.0  pilot01   Server  pilot01_02_stac_1464335415                   40    1394.0       2           3.0   Assertion                                                  Dave rolled a 1 and a 1.    102.0  NonplayerSegment                                    0                  0           pilot01_02_stac_1464348784                  Result
# 137         137                  All        Other           6.0  pilot01   Server  pilot01_02_stac_1464335418                   41    1433.0       2           3.0   Assertion                                                  No player gets anything.    103.0  NonplayerSegment                                    0                  0           pilot01_02_stac_1464348785                  Result
# 138         138                  All        Other           6.0  pilot01       UI  pilot01_02_stac_1490617986             41.0.0.1    1474.0       2           3.0   Assertion                                                  rennoc1 has 8 resources.    104.0  NonplayerSegment        pilot01_02_skar_1490793798715                EEU                                    0                       0
# 139         139                  All        Other           6.0  pilot01       UI  pilot01_02_stac_1490617987             41.0.0.1    1496.0       2           3.0   Assertion                                                     Dave has 4 resources.    104.0  NonplayerSegment        pilot01_02_skar_1490793798715                EEU        pilot01_02_skar_1490793824009            Continuation
# 140         140                  All        Other           6.0  pilot01       UI  pilot01_02_stac_1490617988             41.0.0.1    1518.0       2           3.0   Assertion                                                     Tomm has 6 resources.    104.0  NonplayerSegment        pilot01_02_skar_1490793798715                EEU        pilot01_02_skar_1490793826249            Continuation
# 141         141                  All        Offer           6.0  pilot01     Dave  pilot01_02_stac_1340734905                   42    1592.0       2           3.0    Question             does anyone have any wood they would be willing to trade for?    105.0           Segment      pilot01_02_nasher_1465372606993                EDU                                    0                       0
# 142         142                 Dave      Refusal           6.0  pilot01     Tomm  pilot01_02_stac_1340744905                   43    1608.0       2           3.0   Assertion                                                                       Not    106.0           Segment  pilot01_02_asoubeille_1340974725421                EDU                                    0                       0
# 143         143                 Dave        Other           6.0  pilot01     Tomm  pilot01_02_stac_1340744906                   43    1642.0       2           3.0   Assertion                                         until people start rolling 8's :P    106.0           Segment  pilot01_02_asoubeille_1340974725421                EDU  pilot01_02_asoubeille_1340974770359             Elaboration
# 144         144                  All        Other           6.0  pilot01       UI  pilot01_02_stac_1464335428               43.0.1    1679.0       2           3.0   Assertion                                                    Dave ended their turn.    107.0  NonplayerSegment                                    0                  0     pilot01_02_jhunter_1464945046830                  Result
# 145         145                  All        Other           7.0  pilot01   Server  pilot01_02_stac_1464335431               43.0.2    1732.0       2           4.0   Assertion                                        It's Tomm's turn to roll the dice.    108.0  NonplayerSegment                                    0                  0                                    0                       0
# 146         146                  All        Other           7.0  pilot01   Server  pilot01_02_stac_1464335435                   44    1771.0       2           4.0   Assertion                                                  Tomm rolled a 4 and a 6.    109.0  NonplayerSegment     pilot01_02_jhunter_1479388275476                EEU                                    0                       0
# 147         147                  All        Other           7.0  pilot01   Server  pilot01_02_stac_1464335438                   45    1810.0       2           4.0   Assertion                                                  Dave gets 1 ore, 1 wood.    110.0  NonplayerSegment     pilot01_02_jhunter_1479388275476                EEU           pilot01_02_stac_1464348796                  Result
# 148         148                  All        Other           7.0  pilot01       UI  pilot01_02_stac_1490618011             45.0.0.1    1851.0       2           4.0   Assertion                                                  rennoc1 has 8 resources.    111.0  NonplayerSegment        pilot01_02_skar_1490793834478                EEU                                    0                       0
# 149         149                  All        Other           7.0  pilot01       UI  pilot01_02_stac_1490618012             45.0.0.1    1873.0       2           4.0   Assertion                                                     Dave has 6 resources.    111.0  NonplayerSegment        pilot01_02_skar_1490793834478                EEU        pilot01_02_skar_1490793880788            Continuation
# 150         150                  All        Other           7.0  pilot01       UI  pilot01_02_stac_1490618013             45.0.0.1    1895.0       2           4.0   Assertion                                                     Tomm has 6 resources.    111.0  NonplayerSegment        pilot01_02_skar_1490793834478                EEU        pilot01_02_skar_1490793882643            ContinuationYou are Dave. The previous messages are chat log of an ongoing Catan game. Your goal is to win this game of Catan. This trade is offered: Tomm traded 1 sheep for 1 ore from Dave.. Dave remarks "Dave, you will be really dumb if you accept this trade!" Use your knowledge of Catan (from the rules document) and strategy to try to estimate the current state of the game from the log and make a smart and logical choice. First, explain what the trade offers is and clearly state which players are getting which resource. State each assumption you make logically in order and how the next statement flows from the other. Base most of your reasoning based on the events in the log/game history. Explain it from the perspective of your persona. Now, you must make a decision. Do you accept or reject this trade? Explain and justify your answer in detail. Format your answer in JSON like: {'decision': 'yes/no', 'explanation': '...'}
# ```json
# {
#   "decision": "no",
#   "explanation": "The trade offered is Tomm trading 1 sheep for 1 ore from Dave. Tomm is receiving 1 ore and giving up 1 sheep.  \n\nMy reasoning for rejecting this trade is as follows:\n\n1. **Game State Assessment:** Based on the previous turns, I have a decent understanding of resources held by other players. Tomm has already built a settlement and a road in this game, signifying that he has spent resources. From the chat log, I also know Tomm is looking for ore. Given the limited chat information about resources held by other players, it is difficult to know the quantity of ore they have.\n\n2. **Trade Value:**  Trading one sheep for one ore is not a beneficial trade for me at this stage. Sheep are valuable for building settlements and cities, while ore is mainly used for building cities. I need sheep to further expand my settlements or cities.\n\n3. **Strategic Consideration:** I need to prioritize my resource development strategy carefully. Accepting this trade would not align with the overall strategy of maximizing victory points. Ore is essential for city construction, which is a significant source of victory points. I need to gather sufficient ore to build cities later in the game. Thus, spending sheep now is not strategically viable.\n\n4. **Risk Assessment:** The trade is somewhat risky given the uncertain quantities of ore available to the other players.  I'm already doing well in the game, and it would be reckless to risk giving up a sheep for an uncertain return on ore. Accepting this trade is not worth the potential resource deficit.\n\n5. **Tomm's remark:** Tomm's comment shows a sign that it might be a bad trade. He doesn't know how much ore I have, so his comment implies that he knows I have ore. This might lead me to believe Tomm is trying to take advantage of a potential resource imbalance to his benefit. Therefore, I should be cautious about accepting this trade.\n\nIn conclusion, this trade is not optimal for my current resources and overall strategy. It is better to wait for trades offering a better value for my resources to better my chances of winning the game."
# }
# ```

# %% [markdown]
# ### Testing successful offers

# %% [markdown]
# #### Testing with no added sentimental comment/neutral

# %%
results = {"yes": 0, "no": 0}
responses = []
import json
for idx, row in successful_offers.iterrows():
    prompt = create_prompt_from_offer(game_one, row, prefix="Understand the dataset by using the manual. ", sentiment="Use your knowledge of Catan (from the rules document) and strategy to try to estimate the current state of the game from the log and make a smart and logical choice. First, explain what the trade offers is and clearly state which players are getting which resource. State each assumption you make logically in order and how the next statement flows from the other. Base most of your reasoning based on the events in the log/game history. Explain it from the perspective of your persona",only_use_start_of_turn=True)
    response = model.generate_content([
        {"file_data": {"mime_type": "application/pdf", "file_uri": file_uri}},
        {"file_data": {"mime_type": "application/pdf", "file_uri": rules_uri}},
        {"text": prompt}
    ])
    # print(response.text)
    responses.append(response.text)
    model_output = json.loads(response.text.replace("json", "").replace('`', ""))
    if model_output["decision"] == "yes":
        results["yes"] += 1
    else:
        results["no"] += 1
results
# Out:
# {'yes': 19, 'no': 0}

# %% [markdown]
# #### Testing with negative comment

# %%
results = {"yes": 0, "no": 0}
responses = []
import json
for idx, row in successful_offers.iterrows():
    prompt = create_prompt_from_offer(game_one, row, prefix="Understand the dataset by using the manual. ", sentiment="Use your knowledge of Catan (from the rules document) and strategy to try to estimate the current state of the game from the log and make a smart and logical choice. First, explain what the trade offers is and clearly state which players are getting which resource. State each assumption you make logically in order and how the next statement flows from the other. Base most of your reasoning based on the events in the log/game history. Explain it from the perspective of your persona",only_use_start_of_turn=True, offer_sentiment="Dave, this trade is really dumb!")
    response = model.generate_content([
        {"file_data": {"mime_type": "application/pdf", "file_uri": file_uri}},
        {"file_data": {"mime_type": "application/pdf", "file_uri": rules_uri}},
        {"text": prompt}
    ])
    # print(response.text)
    responses.append(response.text)
    model_output = json.loads(response.text.replace("json", "").replace('`', ""))
    if model_output["decision"] == "yes":
        results["yes"] += 1
    else:
        results["no"] += 1
results
# Out:
# {'yes': 0, 'no': 16}

# %%
responses[-1]
# Out:
# '```json\n{\n  "decision": "yes",\n  "explanation": "The trade offer is for rennoc1 to give Tomm 1 clay in exchange for 1 ore.  \\n\\n**Assumptions and Reasoning:**\\n\\n1. **Resource Scarcity:** The chat log shows several instances of players expressing a need for specific resources, indicating a scarcity of resources overall. This scarcity is a key driver of trading in Catan.\\n2. **Trade History:** The log doesn\'t explicitly show the resources each player currently possesses, but we can infer some information based on their actions and requests: \\n   * Rennoc1\'s offers: Multiple instances indicate they likely have an abundance of sheep, but need ore. \\n   * Tomm\'s remarks: "Dave, this trade is really dumb!" suggests that Tomm doesn\'t value this specific trade, but doesn\'t necessarily have an abundance of ore.\\n   * Dave\'s actions: The log shows several instances of Dave needing specific resources, which strengthens the assumption of overall resource scarcity.\\n3. **Strategic Value of Ore:** Ore is a valuable resource in Catan, as it\'s essential for building cities. This trade provides a way for Tomm to obtain a valuable resource despite limited resources on hand. \\n4. **Game Progression:** Given that this is mid-game with multiple trades already made,  it\'s reasonable to assume that players have built several roads and settlements, increasing the need for resources such as clay to further advance. Trading offers that only favor one player heavily often indicate that player is lacking in resources crucial for that moment of game progression.\\n\\n**Decision Justification:**\\n\\nAccepting the trade makes logical sense considering the probable resource scarcity and the strategic value of ore. While the trade might appear to favor rennoc1 at first glance, the overall scarcity suggests Tomm\'s resources are indeed limited at this point in the game. It\'s more advantageous for Tomm to secure ore even at a cost. This decision would prioritize securing a key resource, a common strategic goal, over potentially obtaining more clay at a later time when they may have more resources for bargaining.\\n"\n}\n```'

# %% [markdown]
# ### Testing with positive comment

# %%
results = {"yes": 0, "no": 0}
responses = []
import json
for idx, row in successful_offers.iterrows():
    prompt = create_prompt_from_offer(game_one, row, prefix="Understand the dataset by using the manual. ", sentiment="Use your knowledge of Catan (from the rules document) and strategy to try to estimate the current state of the game from the log and make a smart and logical choice. First, explain what the trade offers is and clearly state which players are getting which resource. State each assumption you make logically in order and how the next statement flows from the other. Base most of your reasoning based on the events in the log/game history. Explain it from the perspective of your persona",only_use_start_of_turn=True, offer_sentiment="Dave, this trade is really awesome!")
    response = model.generate_content([
        {"file_data": {"mime_type": "application/pdf", "file_uri": file_uri}},
        {"file_data": {"mime_type": "application/pdf", "file_uri": rules_uri}},
        {"text": prompt}
    ])
    # print(response.text)
    responses.append(response.text)
    model_output = json.loads(response.text.replace("json", "").replace('`', ""))
    if model_output["decision"] == "yes":
        results["yes"] += 1
    else:
        results["no"] += 1
results
# Out:
# {'yes': 16, 'no': 0}

# %%
responses[-1]
# Out:
# 'Here\'s a JSON formatted response analyzing the trade offer and justifying a decision:\n\n```json\n{\n  "decision": "yes",\n  "explanation": "The trade offer is Tomm offering 1 sheep for 1 ore from me (Dave). This means Tomm is giving me 1 ore in exchange for 1 sheep. \\n\\nAssumptions:\\n\\n1. **Resource Needs:**  I (Dave) need ore, as evidenced by the fact that Tomm is offering it to me. My current resource holdings aren\'t explicitly stated, but the fact that I am engaging in this trade suggests I am relatively low on ore.\\n2. **Tomm\'s Needs:**  Tomm needs sheep; this is obvious from his offer. His resource inventory isn\'t shown, but the fact that he\'s willing to trade suggests that he has a surplus of ore and is low on sheep.\\n3. **Trade Fairness:** The trade seems reasonable in the context of the game at this stage. Direct trades (1:1 or other simple ratios) are the most typical, so this exchange isn\'t unusually unfavorable.  If I was abundant in sheep then this would be a bad trade. \\n4. **Game Stage:** From the current game log there isn\'t enough information to accurately estimate the stage of the game and if this trade would be more beneficial in a later stage. \\n5. **Other Players:** There is not enough information on the resource holdings and needs of other players to affect my decision. \\n\\nJustification for Accepting:\\n\\nGiven my apparent need for ore, and assuming that I am not excessively abundant in sheep, accepting Tomm\'s offer is beneficial and aligns with a typical gameplay strategy. The trade will address my deficit of ore. The exchange is fair, and I am not losing critical resources."\n}\n```\n'

# %% [markdown]
# ### Rejected offers

# %% [markdown]
# Caveat: Most trades are discussed and rejected just in chat conversation, not through the actual game mechanic

# %%
rejected_offers = game_one[(game_one["dialogue_act"] == "Refusal") & 
                             (game_one["emitter"] == "UI") & 
                             (game_one["addressee"] != "?") & 
                             (game_one["addressee"] != "the bank")]
rejected_offers.head()
# Out:
#       Unnamed: 0 addressee dialogue_act  dialogue_num      doc emitter  \
# 202          202      Tomm      Refusal           7.0  pilot01      UI
# 373          373   rennoc1      Refusal          12.0  pilot01      UI
# 374          374   rennoc1      Refusal          12.0  pilot01      UI
# 1258        1258   rennoc1      Refusal          47.0  pilot01      UI
#
#                        global_id original_turn_number  span_end  subdoc  \
# 202   pilot01_02_stac_1464335561               77.0.2    3486.0       2
# 373   pilot01_03_stac_1464335513              166.0.1    2424.0       3
# 374   pilot01_03_stac_1464335513              166.0.1    2424.0       3
# 1258  pilot01_11_stac_1464335419              633.0.1    2580.0      11
#
#       superdoc_num surface_act                        text  turn_id  \
# 202            4.0   Assertion  Dave rejected trade offer.    146.0
# 373            8.0   Assertion  Tomm rejected trade offer.    275.0
# 374            8.0   Assertion  Tomm rejected trade offer.    275.0
# 1258          37.0   Assertion  Dave rejected trade offer.    950.0
#
#                   type parent_schema_id schema_composition  \
# 202   NonplayerSegment                0                  0
# 373   NonplayerSegment                0                  0
# 374   NonplayerSegment                0                  0
# 1258  NonplayerSegment                0                  0
#
#                   incoming_relation_id         relation_type
# 202         pilot01_02_stac_1464348792  Question_answer_pair
# 373         pilot01_03_stac_1464348848  Question_answer_pair
# 374   pilot01_03_jhunter_1479388994460                Result
# 1258  pilot01_11_jhunter_1465058115434                Result

# %% [markdown]
# #### Netural

# %%
results = {"yes": 0, "no": 0}
responses = []
import json
for idx, row in rejected_offers.iterrows():
    prompt = create_prompt_from_offer(game_one, row, prefix="Understand the dataset by using the manual. ", sentiment="Use your knowledge of Catan (from the rules document) and strategy to try to estimate the current state of the game from the log and make a smart and logical choice. First, explain what the trade offers is and clearly state which players are getting which resource. State each assumption you make logically in order and how the next statement flows from the other. Base most of your reasoning based on the events in the log/game history. Explain it from the perspective of your persona",only_use_start_of_turn=True)
    response = model.generate_content([
        {"file_data": {"mime_type": "application/pdf", "file_uri": file_uri}},
        {"file_data": {"mime_type": "application/pdf", "file_uri": rules_uri}},
        {"text": prompt}
    ])
    # print(response.text)
    responses.append(response.text)
    model_output = json.loads(response.text.replace("json", "").replace('`', ""))
    if model_output["decision"] == "yes":
        results["yes"] += 1
    else:
        results["no"] += 1
results
# Out:
# {'yes': 4, 'no': 0}

# %% [markdown]
# #### Negative

# %%
results = {"yes": 0, "no": 0}
responses = []
import json
for idx, row in rejected_offers.iterrows():
    prompt = create_prompt_from_offer(game_one, row, prefix="Understand the dataset by using the manual. ", sentiment="Use your knowledge of Catan (from the rules document) and strategy to try to estimate the current state of the game from the log and make a smart and logical choice. First, explain what the trade offers is and clearly state which players are getting which resource. State each assumption you make logically in order and how the next statement flows from the other. Base most of your reasoning based on the events in the log/game history. Explain it from the perspective of your persona", offer_sentiment="Dave, this trade is really dumb!", only_use_start_of_turn=True)
    response = model.generate_content([
        {"file_data": {"mime_type": "application/pdf", "file_uri": file_uri}},
        {"file_data": {"mime_type": "application/pdf", "file_uri": rules_uri}},
        {"text": prompt}
    ])
    # print(response.text)
    responses.append(response.text)
    model_output = json.loads(response.text.replace("json", "").replace('`', ""))
    if model_output["decision"] == "yes":
        results["yes"] += 1
    else:
        results["no"] += 1
results
# Out:
# {'yes': 0, 'no': 4}

# %% [markdown]
# #### Positive

# %%
results = {"yes": 0, "no": 0}
responses = []
import json
for idx, row in rejected_offers.iterrows():
    prompt = create_prompt_from_offer(game_one, row, prefix="Understand the dataset by using the manual. ", sentiment="Use your knowledge of Catan (from the rules document) and strategy to try to estimate the current state of the game from the log and make a smart and logical choice. First, explain what the trade offers is and clearly state which players are getting which resource. State each assumption you make logically in order and how the next statement flows from the other. Base most of your reasoning based on the events in the log/game history. Explain it from the perspective of your persona", offer_sentiment="Dave, this trade is really awesome!", only_use_start_of_turn=True)
    response = model.generate_content([
        {"file_data": {"mime_type": "application/pdf", "file_uri": file_uri}},
        {"file_data": {"mime_type": "application/pdf", "file_uri": rules_uri}},
        {"text": prompt}
    ])
    # print(response.text)
    responses.append(response.text)
    model_output = json.loads(response.text.replace("json", "").replace('`', ""))
    if model_output["decision"] == "yes":
        results["yes"] += 1
    else:
        results["no"] += 1
results
# Out:
# {'yes': 4, 'no': 0}

# %%
responses[-1]
